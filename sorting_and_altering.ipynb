# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r'C:\Users\cash\Data_Analysis_Files\Excel Files\iTECH1.xlsx')

# %%
df
# Out:
#     ID  Job_ID First_Name   Last_Name         Full_Name  \
# 0    1    1001     Layola        Bera       Layola Bera
# 1    2    1003       Ealy     Michael      Ealy Michael
# 2    3    1002      Kevin        Hart        Kevin Hart
# 3    4    1001     Sophia    Anderson   Sophia Anderson
# 4    5    1004       Liam      Harris       Liam Harris
# 5    6    1007     Olivia    Campbell   Olivia Campbell
# 6    7    1008      Chris      Bonnet      Chris Bonnet
# 7    8    1010      Lucas       Lewis       Lucas Lewis
# 8    9    1006        Mia      Robert        Mia Robert
# 9   10    1004      James      Walker      James Walker
# 10  11    1002     Amelia      Carter     Amelia Carter
# 11  12    1001    Isabell      Miller    Isabell Miller
# 12  13    1005      Aiden       Clark       Aiden Clark
# 13  14    1009  Charlotte      Turner  Charlotte Turner
# 14  15    1010      Henry       Scott       Henry Scott
# 15  16    1003      Chloe       Adams       Chloe Adams
# ...

# %%
describe_df = df[['Salary_Annually', 'Salary_Annum']].describe()

describe_df
# Out:
#        Salary_Annually  Salary_Annum
# count        26.000000     26.000000
# mean     287441.615385  23953.467949
# std      139377.766440  11614.813870
# min      106781.000000   8898.416667
# 25%      200375.000000  16697.916667
# 50%      279988.500000  23332.375000
# 75%      350000.000000  29166.666667
# max      659321.000000  54943.416667

# %%
sorted_by_lastName = df.sort_values('Last_Name')

sorted_by_lastName
# Out:
#     ID  Job_ID First_Name   Last_Name         Full_Name  \
# 15  16    1003      Chloe       Adams       Chloe Adams
# 3    4    1001     Sophia    Anderson   Sophia Anderson
# 0    1    1001     Layola        Bera       Layola Bera
# 6    7    1008      Chris      Bonnet      Chris Bonnet
# 18  19    1001       Owen      Brooks       Owen Brooks
# 5    6    1007     Olivia    Campbell   Olivia Campbell
# 10  11    1002     Amelia      Carter     Amelia Carter
# 12  13    1005      Aiden       Clark       Aiden Clark
# 17  18    1005     Amanda     Dlamini    Amanda Dlamini
# 16  17    1006       Ella      Foster       Ella Foster
# 4    5    1004       Liam      Harris       Liam Harris
# 2    3    1002      Kevin        Hart        Kevin Hart
# 7    8    1010      Lucas       Lewis       Lucas Lewis
# 22  23    1004       Vuyo       Lundi        Vuyo Lundi
# 1    2    1003       Ealy     Michael      Ealy Michael
# 11  12    1001    Isabell      Miller    Isabell Miller
# ...

# %%
sorted_by_salary_Annum = df.sort_values('Salary_Annum')

sorted_by_salary_Annum
# Out:
#     ID  Job_ID First_Name   Last_Name         Full_Name  \
# 21  22    1007       Will       Smith        Will Smith
# 20  21    1008       Jack  Richardson   Jack Richardson
# 19  20    1008     Luyolo      Ndlovu     Luyolo Ndlovu
# 15  16    1003      Chloe       Adams       Chloe Adams
# 14  15    1010      Henry       Scott       Henry Scott
# 6    7    1008      Chris      Bonnet      Chris Bonnet
# 7    8    1010      Lucas       Lewis       Lucas Lewis
# 8    9    1006        Mia      Robert        Mia Robert
# 16  17    1006       Ella      Foster       Ella Foster
# 17  18    1005     Amanda     Dlamini    Amanda Dlamini
# 12  13    1005      Aiden       Clark       Aiden Clark
# 5    6    1007     Olivia    Campbell   Olivia Campbell
# 3    4    1001     Sophia    Anderson   Sophia Anderson
# 25  26    1001      Linda      Xumalo      Linda Xumalo
# 10  11    1002     Amelia      Carter     Amelia Carter
# 23  24    1002     Sifiso       Monde      Sifiso Monde
# ...

# %%
employees_earning_less = sorted_by_salary_Annum.head(5)

employees_earning_less
# Out:
#     ID  Job_ID First_Name   Last_Name        Full_Name           Job_Position  \
# 21  22    1007       Will       Smith       Will Smith  Operations Assistance
# 20  21    1008       Jack  Richardson  Jack Richardson       Customer Service
# 19  20    1008     Luyolo      Ndlovu    Luyolo Ndlovu       Customer Service
# 15  16    1003      Chloe       Adams      Chloe Adams       Finacial Analyst
# 14  15    1010      Henry       Scott      Henry Scott   Marketing Assistance
#
#                 Department Date_Employed  Salary_Annually  Salary_Annum
# 21              Operations    2019-07-31           106781   8898.416667
# 20        Customer Support    2018-07-30           125111  10425.916667
# 19        Customer Support    2018-07-30           125111  10425.916667
# 15  Finance and Accounting    2022-07-25           129050  10754.166667
# 14               Marketing    2023-07-24           134289  11190.750000

# %%
# top five people earning less

employees_earning_less.sort_values('Salary_Annum', ascending=False)
# Out:
#     ID  Job_ID First_Name   Last_Name        Full_Name           Job_Position  \
# 14  15    1010      Henry       Scott      Henry Scott   Marketing Assistance
# 15  16    1003      Chloe       Adams      Chloe Adams       Finacial Analyst
# 20  21    1008       Jack  Richardson  Jack Richardson       Customer Service
# 19  20    1008     Luyolo      Ndlovu    Luyolo Ndlovu       Customer Service
# 21  22    1007       Will       Smith       Will Smith  Operations Assistance
#
#                 Department Date_Employed  Salary_Annually  Salary_Annum
# 14               Marketing    2023-07-24           134289  11190.750000
# 15  Finance and Accounting    2022-07-25           129050  10754.166667
# 20        Customer Support    2018-07-30           125111  10425.916667
# 19        Customer Support    2018-07-30           125111  10425.916667
# 21              Operations    2019-07-31           106781   8898.416667

# %%
employees_earning_more = sorted_by_salary_Annum.tail(5)

employees_earning_more
# Out:
#     ID  Job_ID First_Name Last_Name         Full_Name            Job_Position  \
# 1    2    1003       Ealy   Michael      Ealy Michael        Finacial Analyst
# 11  12    1001    Isabell    Miller    Isabell Miller      Software Developer
# 0    1    1001     Layola      Bera       Layola Bera            Data Analyst
# 13  14    1009  Charlotte    Turner  Charlotte Turner               QA Tester
# 2    3    1002      Kevin      Hart        Kevin Hart  Human Resource Manager
#
#                 Department Date_Employed  Salary_Annually  Salary_Annum
# 1   Finance and Accounting    2022-06-11           355690  29640.833333
# 11                      IT    2018-07-10           451236  37603.000000
# 0                       IT    2018-07-10           465690  38807.500000
# 13       Quality Assurance    2018-07-23           556650  46387.500000
# 2                       HR    2018-07-12           659321  54943.416667

# %%
# top five people earning more

employees_earning_more.sort_values('Salary_Annum', ascending=False)
# Out:
#     ID  Job_ID First_Name Last_Name         Full_Name            Job_Position  \
# 2    3    1002      Kevin      Hart        Kevin Hart  Human Resource Manager
# 13  14    1009  Charlotte    Turner  Charlotte Turner               QA Tester
# 0    1    1001     Layola      Bera       Layola Bera            Data Analyst
# 11  12    1001    Isabell    Miller    Isabell Miller      Software Developer
# 1    2    1003       Ealy   Michael      Ealy Michael        Finacial Analyst
#
#                 Department Date_Employed  Salary_Annually  Salary_Annum
# 2                       HR    2018-07-12           659321  54943.416667
# 13       Quality Assurance    2018-07-23           556650  46387.500000
# 0                       IT    2018-07-10           465690  38807.500000
# 11                      IT    2018-07-10           451236  37603.000000
# 1   Finance and Accounting    2022-06-11           355690  29640.833333

# %%
# List of people by their departments

employees_by_department = df.loc[df['Department'] == 'HR']

employees_by_department
# Out:
#     ID  Job_ID First_Name Last_Name      Full_Name            Job_Position  \
# 2    3    1002      Kevin      Hart     Kevin Hart  Human Resource Manager
# 10  11    1002     Amelia    Carter  Amelia Carter          Human Resource
# 23  24    1002     Sifiso     Monde   Sifiso Monde          Human Resource
#
#    Department Date_Employed  Salary_Annually  Salary_Annum
# 2          HR    2018-07-12           659321  54943.416667
# 10         HR    2019-07-20           322791  26899.250000
# 23         HR    2019-08-02           322791  26899.250000

# %%
setted_index = df.set_index('First_Name')

setted_index
# Out:
#             ID  Job_ID   Last_Name         Full_Name  \
# First_Name
# Layola       1    1001        Bera       Layola Bera
# Ealy         2    1003     Michael      Ealy Michael
# Kevin        3    1002        Hart        Kevin Hart
# Sophia       4    1001    Anderson   Sophia Anderson
# Liam         5    1004      Harris       Liam Harris
# Olivia       6    1007    Campbell   Olivia Campbell
# Chris        7    1008      Bonnet      Chris Bonnet
# Lucas        8    1010       Lewis       Lucas Lewis
# Mia          9    1006      Robert        Mia Robert
# James       10    1004      Walker      James Walker
# Amelia      11    1002      Carter     Amelia Carter
# Isabell     12    1001      Miller    Isabell Miller
# Aiden       13    1005       Clark       Aiden Clark
# Charlotte   14    1009      Turner  Charlotte Turner
# Henry       15    1010       Scott       Henry Scott
# Chloe       16    1003       Adams       Chloe Adams
# ...

# %%
setted_index.plot(figsize=(18,8), xlabel='First_Name')
# Out:
# <Axes: xlabel='First_Name'>

# %%
# List of people by their departments

setted_index.sort_index()
# Out:
#                                                  ID  Job_ID First_Name  \
# Department             Job_Position
# Customer Support       Customer Service           7    1008      Chris
#                        Customer Service          20    1008     Luyolo
#                        Customer Service          21    1008       Jack
# Design                 Graphic Designer          18    1005     Amanda
#                        UI                        13    1005      Aiden
# Finance and Accounting Finacial Analyst           2    1003       Ealy
#                        Finacial Analyst          16    1003      Chloe
#                        Finacial Analyst          25    1003        Zoe
# HR                     Human Resource            11    1002     Amelia
#                        Human Resource            24    1002     Sifiso
#                        Human Resource Manager     3    1002      Kevin
# IT                     Data Analyst               1    1001     Layola
# ...

# %%
groupby_department = df.groupby('Department').agg({'Salary_Annum': ['max', 'min', 'count']})

# %%
plt.style.use('fivethirtyeight')

# %%
df = pd.DataFrame({
    'First_Name': [],
    '': []
})
# Out:
# <Axes: >

# %%
name_list = []
salary_list = []

for index, row in df[['First_Name', 'Salary_Annum']].iterrows():
    name_list.append(row['First_Name'])
    salary_list.append(row['Salary_Annum'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[251], line 4
#       1 name_list = []
#       2 salary_list = []
# ----> 4 for index, row in df[['First_Name', 'Salary_Annum']].iterrows():
#       5     name_list.append(row['First_Name'])
#       6     salary_list.append(row['Salary_Annum'])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...
