# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r'C:\Users\cash\Data_Analysis_Files\Excel Files\Country_Data.xlsx')

# %%
df
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
# shape about rows and columns

df.shape
# Out:
# (1704, 3)

# %%
# information about dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   country     1704 non-null   object
#  1   year        1704 non-null   int64
#  2   population  1704 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 40.1+ KB

# %%
df = df.drop_duplicates()

# %%
# years that in the dataframe, which i will use to for sort, alter and chart

years = df['year'].unique()

print(years)
# Out:
# [1952 1957 1962 1967 1972 1977 1982 1987 1992 1997 2002 2007]

# %%
# style of charts

plt.style.use('fivethirtyeight')

# set diplaying rows
pd.set_option('display.max.row', 10)

# %%
# start by 1952
data_for_1952 = df[df['year'] == 1952].sort_values('population', ascending=False)

# i divided population by 1 million to get small values
data_for_1952['population'] = round(data_for_1952['population'] / 1000000, 2)

data_for_1952
# Out:
#                     country  year  population
# 288                   China  1952      556.26
# 696                   India  1952      372.00
# 1608          United States  1952      157.55
# 792                   Japan  1952       86.46
# 708               Indonesia  1952       82.05
# ...                     ...   ...         ...
# 312                 Comoros  1952        0.15
# 684                 Iceland  1952        0.15
# 84                  Bahrain  1952        0.12
# 420                Djibouti  1952        0.06
# 1296  Sao Tome and Principe  1952        0.06
#
# [142 rows x 3 columns]

# %%
# describing data for year 1952

round(data_for_1952['population'].describe(), 2)
# Out:
# count    142.00
# mean      16.95
# std       58.10
# min        0.06
# 25%        1.45
# 50%        3.94
# 75%        9.17
# max      556.26
# Name: population, dtype: float64

# %%
# for that 142 rows. I divided by 4 to get clear chart for my data, because of big data

data_in_1952 = data_for_1952.head(36)

data_in_1952
# Out:
#             country  year  population
# 288           China  1952      556.26
# 696           India  1952      372.00
# 1608  United States  1952      157.55
# 792           Japan  1952       86.46
# 708       Indonesia  1952       82.05
# ...             ...   ...         ...
# 1080    Netherlands  1952       10.38
# 1020        Morocco  1952        9.94
# 672         Hungary  1952        9.50
# 24          Algeria  1952        9.28
# 1068          Nepal  1952        9.18
#
# [36 rows x 3 columns]

# %%
plt.figure(figsize=(15,8))
plt.scatter(data['country'], data['population'])

plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Population of countries in 1952')

plt.show()

# %%
data_for_1957 = df[df['year'] == 1957].sort_values('population', ascending=False)

data_for_1957['population'] = round(data_for_1957['population'] / 1000000, 2)

data_for_1957
# Out:
#                     country  year  population
# 289                   China  1957      637.41
# 697                   India  1957      409.00
# 1609          United States  1957      171.98
# 793                   Japan  1957       91.56
# 709               Indonesia  1957       90.12
# ...                     ...   ...         ...
# 313                 Comoros  1957        0.17
# 685                 Iceland  1957        0.17
# 85                  Bahrain  1957        0.14
# 421                Djibouti  1957        0.07
# 1297  Sao Tome and Principe  1957        0.06
#
# [142 rows x 3 columns]

# %%
# describing data for year 1957

round(data_for_1957['population'].describe(), 2)
# Out:
# count    142.00
# mean      18.76
# std       65.50
# min        0.06
# 25%        1.57
# 50%        4.28
# 75%        9.82
# max      637.41
# Name: population, dtype: float64

# %%
# for that 142 rows. I divided by 4 to get clear chart for my data, because of big data

data = data_for_1957.head(36)

data
# Out:
#             country  year  population
# 289           China  1957      637.41
# 697           India  1957      409.00
# 1609  United States  1957      171.98
# 793           Japan  1957       91.56
# 709       Indonesia  1957       90.12
# ...             ...   ...         ...
# 1021        Morocco  1957       11.41
# 1081    Netherlands  1957       11.03
# 25          Algeria  1957       10.27
# 1501         Taiwan  1957       10.16
# 673         Hungary  1957        9.84
#
# [36 rows x 3 columns]

# %%
plt.figure(figsize=(15,8))
plt.plot(data['country'], data['population'])

plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Population of countries in 1957')

plt.show()

# %%
data_for_1962 = df[df['year'] == 1962].sort_values('population', ascending=False)

# i divided population by 1 million to get small values
data_for_1962['population'] = round(data_for_1962['population'] / 1000000, 2)

data_for_1962
# Out:
#                     country  year  population
# 290                   China  1962      665.77
# 698                   India  1962      454.00
# 1610          United States  1962      186.54
# 710               Indonesia  1962       99.03
# 794                   Japan  1962       95.83
# ...                     ...   ...         ...
# 314                 Comoros  1962        0.19
# 686                 Iceland  1962        0.18
# 86                  Bahrain  1962        0.17
# 422                Djibouti  1962        0.09
# 1298  Sao Tome and Principe  1962        0.07
#
# [142 rows x 3 columns]

# %%
round(data_for_1962['population'].describe(), 2)
# Out:
# count    142.00
# mean      20.42
# std       69.79
# min        0.07
# 25%        1.78
# 50%        4.69
# 75%       10.98
# max      665.77
# Name: population, dtype: float64

# %%
data = data_for_1962.head(36)

data
# Out:
#             country  year  population
# 290           China  1962      665.77
# 698           India  1962      454.00
# 1610  United States  1962      186.54
# 710       Indonesia  1962       99.03
# 794           Japan  1962       95.83
# ...             ...   ...         ...
# 1022        Morocco  1962       13.06
# 1502         Taiwan  1962       11.92
# 1082    Netherlands  1962       11.81
# 1442          Sudan  1962       11.18
# 26          Algeria  1962       11.00
#
# [36 rows x 3 columns]

# %%
plt.figure(figsize=(15,8))
plt.bar(data['country'], data['population'])

plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Population of countries in 1962')

plt.show()

# %%
data_for_1967 = df[df['year'] == 1967].sort_values('population', ascending=False)

# i divided population by 1 million to get small values
data_for_1967['population'] = round(data_for_1967['population'] / 1000000, 2)

data_for_1967
# Out:
#                     country  year  population
# 291                   China  1967      754.55
# 699                   India  1967      506.00
# 1611          United States  1967      198.71
# 711               Indonesia  1967      109.34
# 795                   Japan  1967      100.83
# ...                     ...   ...         ...
# 315                 Comoros  1967        0.22
# 87                  Bahrain  1967        0.20
# 687                 Iceland  1967        0.20
# 423                Djibouti  1967        0.13
# 1299  Sao Tome and Principe  1967        0.07
#
# [142 rows x 3 columns]

# %%
round(data_for_1967['population'].describe(), 2)
# Out:
# count    142.00
# mean      22.66
# std       78.38
# min        0.07
# 25%        2.03
# 50%        5.17
# 75%       12.62
# max      754.55
# Name: population, dtype: float64

# %%
data_in_1967 = data_for_1967.head(36)

data_in_1967
# Out:
#                country  year  population
# 291              China  1967      754.55
# 699              India  1967      506.00
# 1611     United States  1967      198.71
# 711          Indonesia  1967      109.34
# 795              Japan  1967      100.83
# ...                ...   ...         ...
# 1023           Morocco  1967       14.77
# 1503            Taiwan  1967       13.65
# 27             Algeria  1967       12.76
# 1443             Sudan  1967       12.72
# 831   Korea, Dem. Rep.  1967       12.62
#
# [36 rows x 3 columns]

# %%
plt.figure(figsize=(15,8))
plt.plot(data_in_1967['country'], data_in_1967['population'])

plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Population of countries in 1967')

plt.show()

# %%
data_for_1972 = df[df['year'] == 1972].sort_values('population', ascending=False)

# i divided population by 1 million to get small values
data_for_1972['population'] = round(data_for_1972['population'] / 1000000, 2)

data_for_1972
# Out:
#                     country  year  population
# 292                   China  1972      862.03
# 700                   India  1972      567.00
# 1612          United States  1972      209.90
# 712               Indonesia  1972      121.28
# 796                   Japan  1972      107.19
# ...                     ...   ...         ...
# 316                 Comoros  1972        0.25
# 88                  Bahrain  1972        0.23
# 688                 Iceland  1972        0.21
# 424                Djibouti  1972        0.18
# 1300  Sao Tome and Principe  1972        0.08
#
# [142 rows x 3 columns]

# %%
round(data_for_1972['population'].describe(), 2)
# Out:
# count    142.00
# mean      25.19
# std       88.65
# min        0.08
# 25%        2.35
# 50%        5.88
# 75%       14.68
# max      862.03
# Name: population, dtype: float64

# %%
data_in_1972 = data_for_1972.head(36)

data_in_1972
# Out:
#                country  year  population
# 292              China  1972      862.03
# 700              India  1972      567.00
# 1612     United States  1972      209.90
# 712          Indonesia  1972      121.28
# 796              Japan  1972      107.19
# ...                ...   ...         ...
# 1024           Morocco  1972       16.66
# 1504            Taiwan  1972       15.23
# 832   Korea, Dem. Rep.  1972       14.78
# 28             Algeria  1972       14.76
# 1516          Tanzania  1972       14.71
#
# [36 rows x 3 columns]

# %%
plt.figure(figsize=(15,8))
plt.scatter(data_in_1972['country'], data_in_1972['population'])

plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Population of countries in 1972')

plt.show()

# %%
data_for_1977 = df[df['year'] == 1977].sort_values('population', ascending=False)

# i divided population by 1 million to get small values
data_for_1977['population'] = round(data_for_1977['population'] / 1000000, 2)

data_for_1977
# Out:
#                     country  year  population
# 293                   China  1977      943.46
# 701                   India  1977      634.00
# 1613          United States  1977      220.24
# 713               Indonesia  1977      136.72
# 173                  Brazil  1977      114.31
# ...                     ...   ...         ...
# 89                  Bahrain  1977        0.30
# 425                Djibouti  1977        0.23
# 689                 Iceland  1977        0.22
# 485       Equatorial Guinea  1977        0.19
# 1301  Sao Tome and Principe  1977        0.09
#
# [142 rows x 3 columns]

# %%
round(data_for_1977['population'].describe(), 2)
# Out:
# count    142.00
# mean      27.68
# std       97.48
# min        0.09
# 25%        2.76
# 50%        6.40
# 75%       16.67
# max      943.46
# Name: population, dtype: float64

# %%
data_in_1977 = data_for_1977.head(36)

data_in_1977
# Out:
#             country  year  population
# 293           China  1977      943.46
# 701           India  1977      634.00
# 1613  United States  1977      220.24
# 713       Indonesia  1977      136.72
# 173          Brazil  1977      114.31
# ...             ...   ...         ...
# 1025        Morocco  1977       18.40
# 29          Algeria  1977       17.15
# 1517       Tanzania  1977       17.13
# 1445          Sudan  1977       17.10
# 1505         Taiwan  1977       16.79
#
# [36 rows x 3 columns]

# %%
plt.figure(figsize=(15,8))
plt.bar(data_in_1977['country'], data_in_1977['population'])

plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Population for countries in 1977')

plt.show()

# %%
data_for_1982 = df[df['year'] == 1982].sort_values('population', ascending=False)

# i divided population by 1 million to get small values
data_for_1982['population'] = round(data_for_1982['population'] / 1000000, 2)

data_for_1982
# Out:
#                     country  year  population
# 294                   China  1982     1000.28
# 702                   India  1982      708.00
# 1614          United States  1982      232.19
# 714               Indonesia  1982      153.34
# 174                  Brazil  1982      128.96
# ...                     ...   ...         ...
# 318                 Comoros  1982        0.35
# 426                Djibouti  1982        0.31
# 486       Equatorial Guinea  1982        0.29
# 690                 Iceland  1982        0.23
# 1302  Sao Tome and Principe  1982        0.10
#
# [142 rows x 3 columns]

# %%
round(data_for_1982['population'].describe(), 2)
# Out:
# count     142.00
# mean       30.21
# std       105.10
# min         0.10
# 25%         3.01
# 50%         7.01
# 75%        18.41
# max      1000.28
# Name: population, dtype: float64

# %%
data_in_1982 = data_for_1982.head(36)

data_in_1982
# Out:
#             country  year  population
# 294           China  1982     1000.28
# 702           India  1982      708.00
# 1614  United States  1982      232.19
# 714       Indonesia  1982      153.34
# 174          Brazil  1982      128.96
# ...             ...   ...         ...
# 1446          Sudan  1982       20.37
# 1026        Morocco  1982       20.20
# 30          Algeria  1982       20.03
# 1518       Tanzania  1982       19.84
# 1506         Taiwan  1982       18.50
#
# [36 rows x 3 columns]

# %%
plt.figure(figsize=(15,8))
plt.plot(data_in_1982['country'], data_in_1982['population'])

plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Population of countries in 1982')

plt.show()

# %%
data_for_1987 = df[df['year'] == 1987].sort_values('population', ascending=False)

# i divided population by 1 million to get small values
data_for_1987['population'] = round(data_for_1987['population'] / 1000000, 2)

data_for_1987
# Out:
#                     country  year  population
# 295                   China  1987     1084.04
# 703                   India  1987      788.00
# 1615          United States  1987      242.80
# 715               Indonesia  1987      169.28
# 175                  Brazil  1987      142.94
# ...                     ...   ...         ...
# 319                 Comoros  1987        0.40
# 487       Equatorial Guinea  1987        0.34
# 427                Djibouti  1987        0.31
# 691                 Iceland  1987        0.24
# 1303  Sao Tome and Principe  1987        0.11
#
# [142 rows x 3 columns]

# %%
round(data_for_1987['population'].describe(), 2)
# Out:
# count     142.00
# mean       33.04
# std       114.76
# min         0.11
# 25%         3.19
# 50%         7.77
# 75%        20.95
# max      1084.04
# Name: population, dtype: float64

# %%
data_in_1987 = data_for_1987.head(36)

data_in_1987
# Out:
#             country  year  population
# 295           China  1987     1084.04
# 703           India  1987      788.00
# 1615  United States  1987      242.80
# 715       Indonesia  1987      169.28
# 175          Brazil  1987      142.94
# ...             ...   ...         ...
# 31          Algeria  1987       23.25
# 1519       Tanzania  1987       23.04
# 1027        Morocco  1987       22.99
# 1279        Romania  1987       22.69
# 823           Kenya  1987       21.20
#
# [36 rows x 3 columns]

# %%
plt.figure(figsize=(15,8))
plt.scatter(data_in_1987['country'], data_in_1987['population'])

plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Population of countries in 1987')

plt.show()

# %%
data_for_1992 = df[df['year'] == 1992].sort_values('population', ascending=False)

# i divided population by 1 million to get small values
data_for_1992['population'] = round(data_for_1992['population'] / 1000000, 2)

data_for_1992
# Out:
#                     country  year  population
# 296                   China  1992     1164.97
# 704                   India  1992      872.00
# 1616          United States  1992      256.89
# 716               Indonesia  1992      184.82
# 176                  Brazil  1992      155.98
# ...                     ...   ...         ...
# 320                 Comoros  1992        0.45
# 488       Equatorial Guinea  1992        0.39
# 428                Djibouti  1992        0.38
# 692                 Iceland  1992        0.26
# 1304  Sao Tome and Principe  1992        0.13
#
# [142 rows x 3 columns]

# %%
round(data_for_1992['population'].describe(), 2)
# Out:
# count     142.00
# mean       35.99
# std       124.50
# min         0.13
# 25%         3.61
# 50%         8.69
# 75%        22.71
# max      1164.97
# Name: population, dtype: float64

# %%
data_in_1992 = data_for_1992.head(36)

data_in_1992
# Out:
#             country  year  population
# 296           China  1992     1164.97
# 704           India  1992      872.00
# 1616  United States  1992      256.89
# 716       Indonesia  1992      184.82
# 176          Brazil  1992      155.98
# ...             ...   ...         ...
# 1520       Tanzania  1992       26.61
# 32          Algeria  1992       26.30
# 1028        Morocco  1992       25.80
# 824           Kenya  1992       25.02
# 1280        Romania  1992       22.80
#
# [36 rows x 3 columns]

# %%
plt.figure(figsize=(15,8))
plt.bar(data_in_1992['country'], data_in_1992['population'])

plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Population of countries in 1992')

plt.show()

# %%
data_for_1997 = df[df['year'] == 1997].sort_values('population', ascending=False)

# i divided population by 1 million to get small values
data_for_1997['population'] = round(data_for_1997['population'] / 1000000, 2)

data_for_1997
# Out:
#                     country  year  population
# 297                   China  1997     1230.08
# 705                   India  1997      959.00
# 1617          United States  1997      272.91
# 717               Indonesia  1997      199.28
# 177                  Brazil  1997      168.55
# ...                     ...   ...         ...
# 321                 Comoros  1997        0.53
# 489       Equatorial Guinea  1997        0.44
# 429                Djibouti  1997        0.42
# 693                 Iceland  1997        0.27
# 1305  Sao Tome and Principe  1997        0.15
#
# [142 rows x 3 columns]

# %%
round(data_for_1997['population'].describe(), 2)
# Out:
# count     142.00
# mean       38.84
# std       133.42
# min         0.15
# 25%         3.77
# 50%         9.74
# 75%        24.31
# max      1230.08
# Name: population, dtype: float64

# %%
data_in_1997 = data_for_1997.head(36)

data_in_1997
# Out:
#             country  year  population
# 297           China  1997     1230.08
# 705           India  1997      959.00
# 1617  United States  1997      272.91
# 717       Indonesia  1997      199.28
# 177          Brazil  1997      168.55
# ...             ...   ...         ...
# 249          Canada  1997       30.31
# 33          Algeria  1997       29.07
# 1029        Morocco  1997       28.53
# 825           Kenya  1997       28.26
# 1209           Peru  1997       24.75
#
# [36 rows x 3 columns]

# %%
plt.figure(figsize=(15,8))
plt.plot(data_in_1997['country'], data_in_1997['population'])

plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Population of countries in 1997')

plt.show()

# %%
data_for_2002 = df[df['year'] == 2002].sort_values('population', ascending=False)

# i divided population by 1 million to get small values
data_for_2002['population'] = round(data_for_2002['population'] / 1000000, 2)

data_for_2002
# Out:
#                     country  year  population
# 298                   China  2002     1280.40
# 706                   India  2002     1034.17
# 1618          United States  2002      287.68
# 718               Indonesia  2002      211.06
# 178                  Brazil  2002      179.91
# ...                     ...   ...         ...
# 322                 Comoros  2002        0.61
# 490       Equatorial Guinea  2002        0.50
# 430                Djibouti  2002        0.45
# 694                 Iceland  2002        0.29
# 1306  Sao Tome and Principe  2002        0.17
#
# [142 rows x 3 columns]

# %%
round(data_for_2002['population'].describe(), 2)
# Out:
# count     142.00
# mean       41.46
# std       140.85
# min         0.17
# 25%         4.18
# 50%        10.37
# 75%        26.54
# max      1280.40
# Name: population, dtype: float64

# %%
data_in_2002 = data_for_2002.head(36)

data_in_2002
# Out:
#             country  year  population
# 298           China  2002     1280.40
# 706           India  2002     1034.17
# 1618  United States  2002      287.68
# 718       Indonesia  2002      211.06
# 178          Brazil  2002      179.91
# ...             ...   ...         ...
# 250          Canada  2002       31.90
# 826           Kenya  2002       31.39
# 34          Algeria  2002       31.29
# 1030        Morocco  2002       31.17
# 1210           Peru  2002       26.77
#
# [36 rows x 3 columns]

# %%
plt.figure(figsize=(15,8))
plt.scatter(data_in_2002['country'], data_in_2002['population'])

plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Population of countries in 2002')

plt.show()

# %%
data_for_2007 = df[df['year'] == 2007].sort_values('population', ascending=False)

# i divided population by 1 million to get small values
data_for_2007['population'] = round(data_for_2007['population'] / 1000000, 2)

data_for_2007
# Out:
#                     country  year  population
# 299                   China  2007     1318.68
# 707                   India  2007     1110.40
# 1619          United States  2007      301.14
# 719               Indonesia  2007      223.55
# 179                  Brazil  2007      190.01
# ...                     ...   ...         ...
# 1019             Montenegro  2007        0.68
# 491       Equatorial Guinea  2007        0.55
# 431                Djibouti  2007        0.50
# 695                 Iceland  2007        0.30
# 1307  Sao Tome and Principe  2007        0.20
#
# [142 rows x 3 columns]

# %%
round(data_for_2007['population'].describe(), 2)
# Out:
# count     142.00
# mean       44.02
# std       147.62
# min         0.20
# 25%         4.50
# 50%        10.52
# 75%        31.21
# max      1318.68
# Name: population, dtype: float64

# %%
data_in_2007 = data_for_2007.head(36)

data_in_2007
# Out:
#             country  year  population
# 299           China  2007     1318.68
# 707           India  2007     1110.40
# 1619  United States  2007      301.14
# 719       Indonesia  2007      223.55
# 179          Brazil  2007      190.01
# ...             ...   ...         ...
# 827           Kenya  2007       35.61
# 1031        Morocco  2007       33.76
# 251          Canada  2007       33.39
# 35          Algeria  2007       33.33
# 11      Afghanistan  2007       31.89
#
# [36 rows x 3 columns]

# %%
plt.figure(figsize=(15,8))
plt.bar(data_in_2007['country'], data_in_2007['population'])

plt.xticks(rotation=90)
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Population of countries in 2007')

plt.show()
